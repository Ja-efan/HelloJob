# %%
import dart_fss as dart_fss
import pandas as pd
# Out:
# Error occurred during getting browser(s): random, but was suppressed with fallback.

# %%
api_key = '여기에 API 키를 입력'
dart_fss.set_api_key(api_key="79985b0c504cc0bb5fce093fba4fd0be634e04a5")

corp_list = dart_fss.get_corp_list()

corp_list.corps
# Out:
# [[00434003]다코,
#  [00430964]굿앤엘에스,
#  [00388953]크레디피아제이십오차유동화전문회사,
#  [00179984]연방건설산업,
#  [00420143]브룩스피알아이오토메이션잉크,
#  [00401111]매경아이비아이,
#  [00435534]캐드뱅크,
#  [00430186]엠와이오피삼차유동화전문유한회사,
#  [00430201]엠와이오피이차유동화전문유한회사,
#  [00430210]엠와이오피일차유동화전문유한회사,
#  [00430229]포스미디어,
#  [00140432]축복할렐루야,
#  [00426208]한국전자화학,
#  [00433262]ConnachtCapitalMarketInvestmentLtd.,
#  [00433749]선진아이티,
#  [00433785]팀스코리아,
#  [00196079]에넥스하이테크,
#  [00435048]세이스텝바이스텝혼합형펀드,
#  [00435057]유리알파헷지채권혼합형펀드,
#  [00108843]한기술정보통신,
#  [00443232]다움종합건설,
#  [00248293]한국애치슨,
#  [00455662]고은상사,
#  [00149318]조흥종합건설,
#  [00451347]유니즈유통,
#  [00415105]창대화장품,
#  [00420824]문화종합건설,
#  [00389439]한국종합미디어,
#  [00454016]아이펜텍,
#  [00452072]대홍염공,
#  [00437602]지오항공여행사,
#  [00365518]헤이아니타코리아,
#  [00246967]태산산업개발,
#  [00445559]군포종합시장,
#  [00444657]기우,
#  [00448936]라시도,
#  [00405658]예전미디어,
#  [00410818]세미가,
#  [00416061]대닉스,
#  [00448909]인포핸드,
#  [00445407]지현개발,
#  [00421647]한국부동산신탁제일차유동화전문유한회사,
#  [00421425]ISCCaymanLtd.,
# ...

# %%
all = dart_fss.api.filings.get_corp_code()
all[0]

df = pd.DataFrame(all)

df_listed = df[df['stock_code'].notnull()]
df_non_listed = df[df['stock_code'].isnull()]

# %%
df_listed
# Out:
#        corp_code corp_name                              corp_eng_name  \
# 1947    00260985      한빛네트                            HanbitNet, Inc.
# 1959    00264529      엔플렉스                                 Nplex,Inc.
# 1960    00358545    동서정보기술  Dong Seo Information Technology Co., Ltd.
# 2702    00231567     애드모바일                                       None
# 3774    00359614       리더컴                        LEADER COMM.Co.,Ltd
# ...          ...       ...                                        ...
# 110920  00520887      비상교육                       VISANG EDUCATION INC
# 110921  00269889     누리플렉스                          NuriFlex Co.,Ltd.
# 110922  00633835     HJ중공업     HJ SHIPBUILDING & CONSTRUCTION CO.,LTD
# 110923  01428203   케이씨씨글라스                      KCC GLASS Corporation
# 110952  00408336       인산가                                 INSAN Inc.
#
#        stock_code modify_date
# 1947       036720    20170630
# 1959       040130    20170630
# 1960       055000    20170630
# ...

# %%
df_listed[df_listed['stock_code'] == '005930']
# Out:
#        corp_code corp_name                corp_eng_name stock_code modify_date
# 102615  00126380      삼성전자  SAMSUNG ELECTRONICS CO,.LTD     005930    20250326

# %%
df_non_listed
# Out:
#        corp_code          corp_name  \
# 0       00434003                 다코
# 1       00430964              굿앤엘에스
# 2       00388953  크레디피아제이십오차유동화전문회사
# 3       00179984             연방건설산업
# 4       00420143     브룩스피알아이오토메이션잉크
# ...          ...                ...
# 111069  01912650              대안일레콤
# 111070  00912990               유영산업
# 111071  00100814             포스코이앤씨
# 111072  01915046             엘에이치앤디
# 111073  01529876                 크림
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation       None
# 1                                      Good & LS Co.,Ltd.       None
# 2       Credipia 25th Asset Securitization Specialty L...       None
# 3                                                youn bao       None
# 4                             BROOKS-PRI Automation, Inc.       None
# ...                                                   ...        ...
# ...

# %%
import OpenDartReader


api_key = '79985b0c504cc0bb5fce093fba4fd0be634e04a5'

dart = OpenDartReader(api_key)

dart

# %%
dart.list('삼성전자') # 기업이름 혹은,
# Out:
#      corp_code corp_name stock_code corp_cls  \
# 0     00126380      삼성전자     005930        Y
# 1     00126380      삼성전자     005930        Y
# 2     00126380      삼성전자     005930        Y
# 3     00126380      삼성전자     005930        Y
# 4     00126380      삼성전자     005930        Y
# ...        ...       ...        ...      ...
# 6143  00126380      삼성전자     005930        Y
# 6144  00126380      삼성전자     005930        Y
# 6145  00126380      삼성전자     005930        Y
# 6146  00126380      삼성전자     005930        Y
# 6147  00126380      삼성전자     005930        Y
#
#                                  report_nm        rcept_no  flr_nm  rcept_dt  \
# 0                        주식등의대량보유상황보고서(일반)  20250418000638    삼성물산  20250418
# 1                      임원ㆍ주요주주특정증권등소유상황보고서  20250411001876     서재홍  20250411
# 2          기업설명회(IR)개최(안내공시)                20250408800011    삼성전자  20250408
# 3     연결재무제표기준영업(잠정)실적(공정공시)                20250408800003    삼성전자  20250408
# ...

# %%
dart.company('00126380')
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '전영현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
df_listed.to_excel("./stocked_list.xlsx")
df_non_listed.to_excel("./non_stocked_list.xlsx")

# %%
len(df)
# Out:
# 111074

# %%
df.to_excel("./all_list.xlsx")

# %%
len(df_non_listed)
# Out:
# 107220

# %%
corp_code_df = pd.read_excel("./업종코드-표준산업분류 연계표(22.4.19).xlsx")
corp_code_df.shape
# Out:
# (1727, 25)

# %%
corp_code_df.head()
# Out:
#    Unnamed: 0  2021년 귀속\n업종코드 대분류        대분류.1  중분류 중분류.1   소분류   소분류.1  \
# 0         1.0         11000.0   A  농업, 임업 및 어업  1.0    농업  11.0  작물 재배업
# 1         2.0         11001.0   A  농업, 임업 및 어업  1.0    농업  11.0  작물 재배업
# 2         3.0         11002.0   A  농업, 임업 및 어업  1.0    농업  11.0  작물 재배업
# 3         4.0         11003.0   A  농업, 임업 및 어업  1.0    농업  11.0  작물 재배업
# 4         5.0         11004.0   A  농업, 임업 및 어업  1.0    농업  11.0  작물 재배업
#
#      세분류                 세분류.1  ... 중분류.2  중분류.3 소분류.2   소분류.3  세분류.2  \
# 0  110.0      곡물 및 기타 식량작물 재배업  ...   1.0     농업  11.0  작물 재배업  111.0
# 1  110.0     채소, 화훼작물 및 종묘 재배업  ...   1.0     농업  11.0  작물 재배업  112.0
# 2  110.0     채소, 화훼작물 및 종묘 재배업  ...   1.0     농업  11.0  작물 재배업  112.0
# 3  110.0     채소, 화훼작물 및 종묘 재배업  ...   1.0     농업  11.0  작물 재배업  112.0
# 4  110.0  과실, 음료용 및 향신용 작물 재배업  ...   1.0     농업  11.0  작물 재배업  113.0
#
#                   세분류.3            세세분류.1  연계.1  메인  Unnamed: 24
# ...

# %%
corp_code_df.columns
# Out:
# Index(['Unnamed: 0', '2021년 귀속\n업종코드', '대분류', '대분류.1', '중분류', '중분류.1', '소분류',
#        '소분류.1', '세분류', '세분류.1', '세세분류', '연계', '표준산업\n분류', '대분류.2', '대분류.3',
#        '중분류.2', '중분류.3', '소분류.2', '소분류.3', '세분류.2', '세분류.3', '세세분류.1', '연계.1',
#        '메인', 'Unnamed: 24'],
#       dtype='object')

# %%
corp_code_df["소분류.2"].unique()
# Out:
# array([ 11.,  12.,  14.,  13.,  15.,  20.,  31.,  32.,  51.,  72.,  61.,
#         62.,  71.,  52.,  80., 101., 102., 103., 104., 105., 106., 108.,
#        107., 111., 112., 120., 131., 132., 134., 303., 139., 143., 133.,
#        144., 141., 142., 151., 152., 161., 162., 163., 171., 172., 179.,
#        181., 182., 191., 192., 201., 203., 202., 204., 212., 211., 213.,
#        266., 205., 221., 222., 231., 232., 233., 239., 241., 242., 243.,
#        251., 259., 291., 292., 252., 285., 263., 262., 281., 283., 282.,
#        284., 289., 261., 264., 265., 271., 272., 273., 274., 301., 302.,
#        304., 311., 312., 313., 319., 320., 331., 332., 333., 334., 339.,
#        759.,  nan, 340., 351., 352., 353., 383., 390., 360., 370., 381.,
#        382., 411., 681., 412., 424., 421., 422., 425., 423., 426., 451.,
#        452., 453., 477., 461., 462., 463., 464., 465., 466., 467., 468.,
#        471., 472., 475., 478., 479., 474., 473., 476., 492., 491., 493.,
# ...

# %%
corp_code_df["소분류.3"].unique()
# Out:
# array(['작물 재배업', '축산업', '작물재배 및 축산 관련 서비스업', '작물재배 및 축산 복합농업',
#        '수렵 및 관련 서비스업', '임업', '어로 어업', '양식어업 및 어업관련 서비스업', '석탄 광업',
#        '기타 비금속광물 광업', '철 광업', '비철금속 광업', '토사석 광업', '원유 및 천연가스 채굴업',
#        '광업 지원 서비스업', '도축, 육류 가공 및 저장 처리업', '수산물 가공 및 저장 처리업',
#        '과실, 채소 가공 및 저장 처리업', '동물성 및 식물성 유지 제조업', '낙농제품 및 식용 빙과류 제조업',
#        '곡물 가공품, 전분 및 전분제품 제조업', '동물용 사료 및 조제식품 제조업', '기타 식품 제조업',
#        '알코올 음료 제조업', '비알코올 음료 및 얼음 제조업', '담배 제조업', '방적 및 가공사 제조업',
#        '직물 직조 및 직물제품 제조업', '섬유제품 염색, 정리 및 마무리 가공업', '자동차 신품 부품 제조업',
#        '기타 섬유제품 제조업', '편조의복 제조업', '편조 원단 제조업', '의복 액세서리 제조업', '봉제의복 제조업',
#        '모피제품 제조업', '가죽, 가방 및 유사 제품 제조업', '신발 및 신발 부분품 제조업', '제재 및 목재 가공업',
#        '나무제품 제조업', '코르크 및 조물 제품 제조업', '펄프, 종이 및 판지 제조업',
#        '골판지, 종이 상자 및 종이 용기 제조업', '기타 종이 및 판지 제품 제조업', '인쇄 및 인쇄관련 산업',
#        '기록매체 복제업', '코크스 및 연탄 제조업', '석유 정제품 제조업', '기초 화학물질 제조업',
#        '비료, 농약 및 살균ㆍ살충제 제조업', '합성고무 및 플라스틱 물질 제조업', '기타 화학제품 제조업',
# ...

# %%
induty_code = corp_code_df['소분류.2']

# %%
induty_code
# Out:
# 0        11.0
# 1        11.0
# 2        11.0
# 3        11.0
# 4        11.0
#         ...
# 1722    990.0
# 1723    715.0
# 1724    715.0
# 1725    981.0
# 1726    982.0
# Name: 소분류.2, Length: 1727, dtype: float64

# %%
induty_name = corp_code_df['소분류.3']

# %%
induty_name
# Out:
# 0                    작물 재배업
# 1                    작물 재배업
# 2                    작물 재배업
# 3                    작물 재배업
# 4                    작물 재배업
#                ...
# 1722              국제 및 외국기관
# 1723     회사본부 및 경영 컨설팅 서비스업
# 1724     회사본부 및 경영 컨설팅 서비스업
# 1725     자가 소비를 위한 가사 생산 활동
# 1726    자가 소비를 위한 가사 서비스 활동
# Name: 소분류.3, Length: 1727, dtype: object

# %%
induty_df = pd.DataFrame({'induty_code': induty_code, 'induty_name': induty_name})

# %%
induty_df.head()
# Out:
#    induty_code induty_name
# 0         11.0      작물 재배업
# 1         11.0      작물 재배업
# 2         11.0      작물 재배업
# 3         11.0      작물 재배업
# 4         11.0      작물 재배업

# %%
induty_df[induty_df['induty_code'].isnull()]
# Out:
#       induty_code induty_name
# 623           NaN     해당사항 없음
# 1244          NaN         확인중
# 1629          NaN     해당사항 없음

# %%
induty_df.dropna(inplace=True)

# %%
induty_df[induty_df['induty_code'].isnull()]
# Out:
# Empty DataFrame
# Columns: [induty_code, induty_name]
# Index: []

# %%
induty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1724 entries, 0 to 1726
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   induty_code  1724 non-null   float64
#  1   induty_name  1724 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 40.4+ KB

# %%
induty_df['induty_code'] = induty_df['induty_code'].apply(lambda x: f'{int(x):03d}')

# %%
induty_df.head()
# Out:
#   induty_code induty_name
# 0         011      작물 재배업
# 1         011      작물 재배업
# 2         011      작물 재배업
# 3         011      작물 재배업
# 4         011      작물 재배업

# %%
induty_df.drop_duplicates(inplace=True)

# %%
induty_df.shape
# Out:
# (235, 2)

# %%
induty_df['induty_code'].unique()
# Out:
# array(['011', '012', '014', '013', '015', '020', '031', '032', '051',
#        '072', '061', '062', '071', '052', '080', '101', '102', '103',
#        '104', '105', '106', '108', '107', '111', '112', '120', '131',
#        '132', '134', '303', '139', '143', '133', '144', '141', '142',
#        '151', '152', '161', '162', '163', '171', '172', '179', '181',
#        '182', '191', '192', '201', '203', '202', '204', '212', '211',
#        '213', '266', '205', '221', '222', '231', '232', '233', '239',
#        '241', '242', '243', '251', '259', '291', '292', '252', '285',
#        '263', '262', '281', '283', '282', '284', '289', '261', '264',
#        '265', '271', '272', '273', '274', '301', '302', '304', '311',
#        '312', '313', '319', '320', '331', '332', '333', '334', '339',
#        '759', '340', '351', '352', '353', '383', '390', '360', '370',
#        '381', '382', '411', '681', '412', '424', '421', '422', '425',
# ...

# %%
induty_df[induty_df['induty_code'] == '264']
# Out:
#     induty_code    induty_name
# 528         264  통신 및 방송장비 제조업

# %%
df.head()
# Out:
#   corp_code          corp_name  \
# 0  00434003                 다코
# 1  00430964              굿앤엘에스
# 2  00388953  크레디피아제이십오차유동화전문회사
# 3  00179984             연방건설산업
# 4  00420143     브룩스피알아이오토메이션잉크
#
#                                        corp_eng_name stock_code modify_date
# 0                                   Daco corporation       None    20170630
# 1                                 Good & LS Co.,Ltd.       None    20170630
# 2  Credipia 25th Asset Securitization Specialty L...       None    20170630
# 3                                           youn bao       None    20170630
# 4                        BROOKS-PRI Automation, Inc.       None    20170630

# %%
samsung  = dart.company('삼성전자') # 기업이름 혹은,

# %%
samsung['induty_code']
# Out:
# '264'

# %%
df_listed['induty_code'] = df_listed['corp_code'].apply(lambda x: dart.company(x)['induty_code'])
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_35244\994305385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listed['induty_code'] = df_listed['corp_code'].apply(lambda x: dart.company(x)['induty_code'])

# %%
df_listed.head()
# Out:
#      corp_code corp_name                              corp_eng_name  \
# 1947  00260985      한빛네트                            HanbitNet, Inc.
# 1959  00264529      엔플렉스                                 Nplex,Inc.
# 1960  00358545    동서정보기술  Dong Seo Information Technology Co., Ltd.
# 2702  00231567     애드모바일                                       None
# 3774  00359614       리더컴                        LEADER COMM.Co.,Ltd
#
#      stock_code modify_date induty_code
# 1947     036720    20170630       58221
# 1959     040130    20170630       58221
# 1960     055000    20170630       58221
# 2702     032600    20170630       58221
# 3774     056140    20170630       26410

# %%
df_listed[df_listed["corp_name"] == "삼성전자"]
# Out:
#        corp_code corp_name                corp_eng_name stock_code  \
# 102615  00126380      삼성전자  SAMSUNG ELECTRONICS CO,.LTD     005930
#
#        modify_date induty_code
# 102615    20250326         264

# %%
df_listed.to_excel("./stocked_list_with_induty_code.xlsx")

# %%
corp_code_df.columns
# Out:
# Index(['Unnamed: 0', '2021년 귀속\n업종코드', '대분류', '대분류.1', '중분류', '중분류.1', '소분류',
#        '소분류.1', '세분류', '세분류.1', '세세분류', '연계', '표준산업\n분류', '대분류.2', '대분류.3',
#        '중분류.2', '중분류.3', '소분류.2', '소분류.3', '세분류.2', '세분류.3', '세세분류.1', '연계.1',
#        '메인', 'Unnamed: 24'],
#       dtype='object')

# %%
corp_code_df["소분류.3"].unique()
# Out:
# array(['작물 재배업', '축산업', '작물재배 및 축산 관련 서비스업', '작물재배 및 축산 복합농업',
#        '수렵 및 관련 서비스업', '임업', '어로 어업', '양식어업 및 어업관련 서비스업', '석탄 광업',
#        '기타 비금속광물 광업', '철 광업', '비철금속 광업', '토사석 광업', '원유 및 천연가스 채굴업',
#        '광업 지원 서비스업', '도축, 육류 가공 및 저장 처리업', '수산물 가공 및 저장 처리업',
#        '과실, 채소 가공 및 저장 처리업', '동물성 및 식물성 유지 제조업', '낙농제품 및 식용 빙과류 제조업',
#        '곡물 가공품, 전분 및 전분제품 제조업', '동물용 사료 및 조제식품 제조업', '기타 식품 제조업',
#        '알코올 음료 제조업', '비알코올 음료 및 얼음 제조업', '담배 제조업', '방적 및 가공사 제조업',
#        '직물 직조 및 직물제품 제조업', '섬유제품 염색, 정리 및 마무리 가공업', '자동차 신품 부품 제조업',
#        '기타 섬유제품 제조업', '편조의복 제조업', '편조 원단 제조업', '의복 액세서리 제조업', '봉제의복 제조업',
#        '모피제품 제조업', '가죽, 가방 및 유사 제품 제조업', '신발 및 신발 부분품 제조업', '제재 및 목재 가공업',
#        '나무제품 제조업', '코르크 및 조물 제품 제조업', '펄프, 종이 및 판지 제조업',
#        '골판지, 종이 상자 및 종이 용기 제조업', '기타 종이 및 판지 제품 제조업', '인쇄 및 인쇄관련 산업',
#        '기록매체 복제업', '코크스 및 연탄 제조업', '석유 정제품 제조업', '기초 화학물질 제조업',
#        '비료, 농약 및 살균ㆍ살충제 제조업', '합성고무 및 플라스틱 물질 제조업', '기타 화학제품 제조업',
# ...

# %%
corp_code_df[corp_code_df["소분류.3"] == "통신 및 방송장비 제조업"]
# Out:
#      Unnamed: 0  2021년 귀속\n업종코드 대분류 대분류.1   중분류  \
# 528       508.0        322002.0   C   제조업  32.0
# 529       509.0        322003.0   C   제조업  32.0
# 530       510.0        322004.0   C   제조업  32.0
# 531       511.0        322005.0   C   제조업  32.0
#
#                              중분류.1    소분류          소분류.1     세분류  \
# 528  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  322.0  통신 및 방송장비 제조업  3220.0
# 529  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  322.0  통신 및 방송장비 제조업  3220.0
# 530  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  322.0  통신 및 방송장비 제조업  3220.0
# 531  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  322.0  통신 및 방송장비 제조업  3220.0
#
#                 세분류.1  ... 중분류.2                          중분류.3  소분류.2  \
# 528       유선 통신장비 제조업  ...  26.0  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  264.0
# 529  방송 및 무선 통신장비 제조업  ...  26.0  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  264.0
# 530  방송 및 무선 통신장비 제조업  ...  26.0  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  264.0
# 531  방송 및 무선 통신장비 제조업  ...  26.0  전자 부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  264.0
#
# ...

# %%
corp_code_df = pd.read_excel("./업종코드-표준산업분류 연계표(22.4.19).xlsx")
corp_code_df.columns
# Out:
# Index(['Unnamed: 0', '2021년 귀속\n업종코드', '대분류', '대분류.1', '중분류', '중분류.1', '소분류',
#        '소분류.1', '세분류', '세분류.1', '세세분류', '연계', '표준산업분류', '대분류.2', '대분류.3',
#        '중분류.2', '중분류.3', '소분류.2', '소분류.3', '세분류.2', '세분류.3', '세세분류.1', '연계.1',
#        '메인', 'Unnamed: 24'],
#       dtype='object')

# %%
corp_code_df[corp_code_df["표준산업분류"] == "264"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 2021년 귀속
# 업종코드, 대분류, 대분류.1, 중분류, 중분류.1, 소분류, 소분류.1, 세분류, 세분류.1, 세세분류, 연계, 표준산업분류, 대분류.2, 대분류.3, 중분류.2, 중분류.3, 소분류.2, 소분류.3, 세분류.2, 세분류.3, 세세분류.1, 연계.1, 메인, Unnamed: 24]
# Index: []
#
# [0 rows x 25 columns]

# %%
df_with_induty_name = pd.read_csv("Revised_Industry_Names_Mapping.csv")

# %%
df_with_induty_name.head()
# Out:
#    Unnamed: 0  corp_code corp_name                              corp_eng_name  \
# 0        1947     260985      한빛네트                            HanbitNet, Inc.
# 1        1959     264529      엔플렉스                                 Nplex,Inc.
# 2        1960     358545    동서정보기술  Dong Seo Information Technology Co., Ltd.
# 3        2702     231567     애드모바일                                        NaN
# 4        3774     359614       리더컴                        LEADER COMM.Co.,Ltd
#
#    stock_code  modify_date  induty_code   induty_name
# 0       36720     20170630        58221       Unknown
# 1       40130     20170630        58221       Unknown
# 2       55000     20170630        58221       Unknown
# 3       32600     20170630        58221       Unknown
# 4       56140     20170630        26410  비금속 광물제품 제조업

# %%
df_with_induty_name[df_with_induty_name["corp_name"] == "삼성전자"]
# Out:
#       Unnamed: 0  corp_code corp_name                corp_eng_name  \
# 2724      102615     126380      삼성전자  SAMSUNG ELECTRONICS CO,.LTD
#
#       stock_code  modify_date  induty_code   induty_name
# 2724        5930     20250326          264  비금속 광물제품 제조업
